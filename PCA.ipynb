# %% [markdown]
# <a href="https://colab.research.google.com/github/XIOZ119/colab/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.decomposition import PCA
from sklearn import datasets
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np

# Iris 데이터셋 불러오기
iris = datasets.load_iris()
print(list(iris.keys()))  # Iris 데이터셋의 키 확인

# 특성 데이터 및 타겟 레이블 설정
X = iris["data"][:, 0:4]
label = iris["target"]

# PCA를 사용하여 2차원으로 차원 축소
pca = PCA(n_components=2)
X2D = pca.fit_transform(X)

# 각 클래스에 대한 색상 설정
colors = ['red', 'green', 'blue']

# 각 클래스에 대해 PCA로 변환된 데이터를 산점도로 시각화
for i, j in enumerate(np.unique(label)):
    plt.scatter(X2D[label == j, 0], X2D[label == j, 1],
                c=colors[i], label=str(j))
plt.legend()  # 범례 표시
plt.show()  # 그래프 출력
# Out:
# ['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module']
